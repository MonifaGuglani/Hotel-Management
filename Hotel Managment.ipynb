# %%
import pymongo

client=pymongo.MongoClient("mongodb://localhost:27017")

db=client["pyproject"]
 
def Menuandbill(name,phone):
        MenuItems=["1) Pizza","2) Burger","3) Chowmin","4) Idli","5) Dosa","6) Wada","7) Shahi Panner ","8) Khadai Panner","9) Matar Panner","10) Garlic Naan","11) Butter Roti","12) Rumali Roti"]
        Pricing=[150,50,80,60,100,250,100,150,250,20,15,5]
        print(f"{name} Our Items is:-\n")
        for i,j in enumerate(MenuItems):
            print(i)
            print(f"{j} :- ₹{Pricing[i]}")
            
        Item1=0
        Item2=0
        Item3=0
        Item4=0
        Item5=0
        Item6=0
        Item7=0
        Item8=0
        Item9=0
        Item10=0
        Item11=0
        Item12=0

        ItemQuaninity1=1
        ItemQuaninity2=1
        ItemQuaninity3=1
        ItemQuaninity4=1
        ItemQuaninity5=1
        ItemQuaninity6=1
        ItemQuaninity7=1
        ItemQuaninity8=1
        ItemQuaninity9=1
        ItemQuaninity10=1
        ItemQuaninity11=1
        ItemQuaninity12=1

        i=1
        while(i==1):
            
            print("")
            choice=input("Enter Item No. :-")
            if(choice.isdigit()):
                ch=int(choice)
                match ch:
                    case 1:
                        Item1=1

                        print("Pizza is Selected")
                        ItemQuaninity1=int(input("Enter the Quaninity if more than one else press 0:-"))
                        if(ItemQuaninity1<=0):
                            ItemQuaninity1=1
                    case 2:
                        print("Burger is Selected")
                        Item2=1
                        ItemQuaninity2=int(input("Enter the Quaninity if more than one else press 0:-"))
                        if(ItemQuaninity2<=0):
                            ItemQuaninity2=1
                    case 3:
                        print("Chowmin is Selected")
                        ItemQuaninity2=int(input("Enter the Quaninity if more than one else press 0:-"))
                        if(ItemQuaninity2<=0):
                            ItemQuaninity1=1
                        Item3=1
                    case 4:
                        print("Idli is Selected")
                        ItemQuaninity4=int(input("Enter the Quaninity if more than one else press 0:-"))
                        if(ItemQuaninity4<=0):
                            ItemQuaninity4=1
                        Item4=1
                    case 5:
                        print("Dosa is Selected")
                        ItemQuaninity5=int(input("Enter the Quaninity if more than one else press 0:-"))
                        if(ItemQuaninity5<=0):
                            ItemQuaninity5=1
                        Item5=1
                    case 6:
                        print("Wada is Selected")
                        ItemQuaninity6=int(input("Enter the Quaninity if more than one else press 0:-"))
                        if(ItemQuaninity6<=0):
                            ItemQuaninity6=1
                        Item6=1
                    case 7:
                        print("Shahi Panner is Selected")
                        ItemQuaninity7=int(input("Enter the Quaninity if more than one else press 0:-"))
                        if(ItemQuaninity7<=0):
                            ItemQuaninity7=1
                        Item7=1
                    case 8:
                        print("Khadai Panner is Selected")
                        ItemQuaninity8=int(input("Enter the Quaninity if more than one else press 0:-"))
                        if(ItemQuaninity8<=0):
                            ItemQuaninity8=1
                        Item8=1
                    case 9:
                        print("Matar Panner is Selected")
                        ItemQuaninity9=int(input("Enter the Quaninity if more than one else press 0:-"))
                        if(ItemQuaninity9<=0):
                            ItemQuaninity9=1
                        Item9=1
                    case 10:
                        print("Garlic Naan is Selected")
                        ItemQuaninity10=int(input("Enter the Quaninity if more than one else press 0:-"))
                        if(ItemQuaninity10<=0):
                            ItemQuaninity10=1
                        Item10=1
                    case 11:
                        print("Butter Roti is Selected")
                        ItemQuaninity11=int(input("Enter the Quaninity if more than one else press 0:-"))
                        if(ItemQuaninity11<=0):
                            ItemQuaninity11=1
                        Item11=1
                    case 12:
                        print("Rumali is Selected")
                        ItemQuaninity12=int(input("Enter the Quaninity if more than one else press 0:-"))
                        if(ItemQuaninity12<=0):
                            ItemQuaninity12=1
                        Item12=1
                    case _:
                        print("Wrong Choice Enter")
            else:
                print("Please enter a digit")
            
            i=int(input("Press 1: for more else Press any key"))
            
               
        Totalpricing=0
        
        print("Your Final Order is: ")
        print(f"{"Items":<15}{"Quantity":<20}{"Price":<20}{"Value":<13}")
        varallorder=[]
        if(Item1>0):
                
                itemTotal=ItemQuaninity2 *Pricing[1]
                Totalpricing += itemTotal
                obj1={
                    "Item":MenuItems[1],
                    "Quantity":ItemQuaninity1,
                    "Itemprice":Pricing[1],
                    "Itemtotal":itemTotal 
                }
                varallorder.append(obj1)
                print(f"{MenuItems[1]:<15}{ItemQuaninity2:<20}₹{Pricing[1]:<20}₹{itemTotal:<13}")           
        if(Item2>0):
                itemTotal=ItemQuaninity2 *Pricing[1]
                Totalpricing += itemTotal
                obj1={
                    "Item":MenuItems[1],
                    "Quantity":ItemQuaninity1,
                    "Itemprice":Pricing[1],
                    "Itemtotal":itemTotal 
                }
                varallorder.append(obj1)
                print(f"{MenuItems[1]:<15}{ItemQuaninity2:<20}₹{Pricing[1]:<20}₹{itemTotal:<13}")
                            
        if(Item3>0):
                itemTotal=ItemQuaninity3 *Pricing[2]
                Totalpricing += itemTotal
                obj1={
                    "Item":MenuItems[2],
                    "Quantity":ItemQuaninity1,
                    "Itemprice":Pricing[2],
                    "Itemtotal":itemTotal 
                }
                varallorder.append(obj1)            
                print(f"{MenuItems[2]:<15}{ItemQuaninity3:<20}₹{Pricing[2]:<20}₹{itemTotal:<13}")

        if(Item4>0):
                itemTotal=ItemQuaninity4 *Pricing[3]
                Totalpricing += itemTotal
                obj1={
                    "Item":MenuItems[3],
                    "Quantity":ItemQuaninity1,
                    "Itemprice":Pricing[3],
                    "Itemtotal":itemTotal 
                }
                varallorder.append(obj1)            
                print(f"{MenuItems[3]:<15}{ItemQuaninity4:<20}₹{Pricing[3]:<20}₹{itemTotal:<13}")
        if(Item5>0):
                itemTotal=ItemQuaninity5 *Pricing[4]
                Totalpricing += itemTotal
                
                obj1={
                    "Item":MenuItems[4],
                    "Quantity":ItemQuaninity1,
                    "Itemprice":Pricing[4],
                    "Itemtotal":itemTotal 
                }
                varallorder.append(obj1)            
                print(f"{MenuItems[4]:<15}{ItemQuaninity5:<20}₹{Pricing[4]:<20}₹{itemTotal:<13}")
                
        if(Item6>0):
                itemTotal=ItemQuaninity6 *Pricing[5]
                Totalpricing += itemTotal  
                obj1={
                    "Item":MenuItems[5],
                    "Quantity":ItemQuaninity1,
                    "Itemprice":Pricing[5],
                    "Itemtotal":itemTotal 
                }
                varallorder.append(obj1)          
                print(f"{MenuItems[5]:<15}{ItemQuaninity6:<20}₹{Pricing[5]:<20}₹{itemTotal:<13}")

        if(Item7>0):
                itemTotal=ItemQuaninity7 *Pricing[6]
                Totalpricing += itemTotal   
                obj1={
                    "Item":MenuItems[6],
                    "Quantity":ItemQuaninity1,
                    "Itemprice":Pricing[6],
                    "Itemtotal":itemTotal 
                }
                varallorder.append(obj1)         
                print(f"{MenuItems[6]:<15}{ItemQuaninity7:<20}₹{Pricing[6]:<20}₹{itemTotal:<13}")

        if(Item8>0):
                itemTotal=ItemQuaninity8 *Pricing[7]
                Totalpricing += itemTotal
                obj1={
                    "Item":MenuItems[7],
                    "Quantity":ItemQuaninity1,
                    "Itemprice":Pricing[7],
                    "Itemtotal":itemTotal 
                }
                varallorder.append(obj1)            
                print(f"{MenuItems[7]:<15}{ItemQuaninity8:<20}₹{Pricing[7]:<20}₹{itemTotal:<13}")

        if(Item9>0):
                itemTotal=ItemQuaninity9 *Pricing[8]
                Totalpricing += itemTotal
                obj1={
                    "Item":MenuItems[8],
                    "Quantity":ItemQuaninity1,
                    "Itemprice":Pricing[8],
                    "Itemtotal":itemTotal 
                }
                varallorder.append(obj1)            
                print(f"{MenuItems[8]:<15}{ItemQuaninity9:<20}₹{Pricing[8]:<20}₹{itemTotal:<13}")

        if(Item10>0):
                itemTotal=ItemQuaninity10 *Pricing[9]
                Totalpricing += itemTotal    
                obj1={
                    "Item":MenuItems[9],
                    "Quantity":ItemQuaninity1,
                    "Itemprice":Pricing[9],
                    "Itemtotal":itemTotal 
                }
                varallorder.append(obj1)        
                print(f"{MenuItems[9]:<15}{ItemQuaninity10:<20}₹{Pricing[9]:<20}₹{itemTotal:<13}")


        if(Item11>0):
                itemTotal=ItemQuaninity11 *Pricing[10]
                Totalpricing += itemTotal    
                obj1={
                    "Item":MenuItems[10],
                    "Quantity":ItemQuaninity1,
                    "Itemprice":Pricing[0],
                    "Itemtotal":itemTotal 
                }
                varallorder.append(obj1)        
                print(f"{MenuItems[10]:<15}{ItemQuaninity11:<20}₹{Pricing[10]:<20}₹{itemTotal:<13}")

        if(Item12>0):
                itemTotal=ItemQuaninity12 *Pricing[11]
                Totalpricing += itemTotal    
                obj1={
                    "Item":MenuItems[11],
                    "Quantity":ItemQuaninity1,
                    "Itemprice":Pricing[11],
                    "Itemtotal":itemTotal 
                }
                varallorder.append(obj1)        
                print(f"{MenuItems[11]:<15}{ItemQuaninity12:<20}₹{Pricing[11]:<20}₹{itemTotal:<13}")
        mainorder={
                    "order":varallorder,
                    "userphoneno":phone,
                    "Ordervalue":Totalpricing
                }
        var=db['orders'].insert_one(mainorder)
        print("="*45)
        print(f"{'Total Price':<55}₹{Totalpricing:<10}")    
def printbill(arr,orderval):
    print("Your Last Order is: ")
    print(f"{"Items":<15}{"Quantity":<20}{"Price":<20}{"Value":<13}")
    for i in arr:
        print(f"{i["Item"]:<15}{i["Quantity"]:<20}₹{i["Itemprice"]:<20}₹{i["Itemtotal"]:<13}")
        # print(i)
    print("="*45)
    print(f"{'Total Price':<55}₹{orderval:<10}")
    
print("Welcome to our Restaurant")
print("Press 1: for New Customer ")
print("Press 2: for Existing Customer ")
print("Press 3: for Find Order ")
Mainchoice=input("Enter Your Choice")
if(Mainchoice.isdigit()):
      ch=int(Mainchoice)
      match ch:
        case 1:
            Name=input("Enter Your Name:-")
            Email=input("Enter Your Email:-")
            Phone=input("Enter Your Phone No.:-")
            Address=input("Enter Your Address.:-")
            if(Phone.isdigit() and len(Phone)==10):   
                alreadyexist=db['users'].find_one({"Phone":Phone})
                if(alreadyexist==None):
                    obj={
                        "Name":Name,
                        "Phone":Phone,
                        "Address":Address
                    }
                    var=db['users'].insert_one(obj)
                    Menuandbill(Name,Phone)
                else:
                    print("Customer already registerd")   
            else:
                print("Wrong Phone Number Enterd")
        case 2:
            Phone=input("Enter Your Phone No.:-")
            if(Phone.isdigit() and len(Phone)==10):
                var=db['users'].find_one({"Phone":Phone})
                if(var==None):
                    print("No registerd Customer found Please register")
                else:
                    Name=var["Name"]
                    Menuandbill(Name,Phone)
            else:
                print("Wrong Phone Number Enterd") 
        case 3:
                Phone=input("Enter Your Phone No.:-")
                if(Phone.isdigit() and len(Phone)==10):
                    var=db['users'].find_one({"Phone":Phone})
                    if(var==None):
                        print("No registerd Customer found Please register")
                    else:
                        order=db["orders"].find_one({"userphoneno":Phone})
                        # for i in order:
                        printbill(order["order"],order["Ordervalue"])
                else:
                    print("Enter 10 digit Phone no.")
        case _:
            print("Wrong Choice")      
else:
    print("please enter a digit")
# Out:
# Welcome to our Restaurant
# Press 1: for New Customer
# Press 2: for Existing Customer
# Press 3: for Find Order
